# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf 
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA

# %%
series = pd.read_csv("https://raw.githubusercontent.com/nguye639/Stat773Project/main/cleanData.csv")

# %%
series
# Out:
#       Unnamed: 0        Date      AAPL      AMZN     FSPTX     SHRAX       SPY
# 0              0  2017-11-06  0.000000  0.000000  0.000000  0.000000  0.000000
# 1              1  2017-11-07  0.008934  0.014056  0.002510 -0.002462  0.002594
# 2              2  2017-11-08  0.013285  0.012325  0.006747 -0.004167  0.000658
# 3              3  2017-11-09  0.015896  0.015156 -0.000889 -0.006771 -0.002207
# 4              4  2017-11-10  0.015896  0.015282  0.004132 -0.007150 -0.002207
# ...          ...         ...       ...       ...       ...       ...       ...
# 1254        1254  2022-10-31  2.554215  0.867376 -0.033000 -0.464012  0.496090
# 1255        1255  2022-11-01  2.598770  0.875130 -0.038230 -0.465006  0.510414
# 1256        1256  2022-11-02  2.456518  0.754857 -0.074839 -0.482811  0.486256
# 1257        1257  2022-11-03  2.296629  0.667403 -0.099943 -0.484894  0.438134
# 1258        1258  2022-11-04  2.297326  0.649732 -0.092098 -0.481438  0.459543
#
# [1259 rows x 7 columns]

# %%
series.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AAPL', 'AMZN', 'FSPTX', 'SHRAX', 'SPY'], dtype='object')

# %%
series = series.drop("Unnamed: 0", axis = 1)

# %%
series
# Out:
#             Date      AAPL      AMZN     FSPTX     SHRAX       SPY
# 0     2017-11-06  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     2017-11-07  0.008934  0.014056  0.002510 -0.002462  0.002594
# 2     2017-11-08  0.013285  0.012325  0.006747 -0.004167  0.000658
# 3     2017-11-09  0.015896  0.015156 -0.000889 -0.006771 -0.002207
# 4     2017-11-10  0.015896  0.015282  0.004132 -0.007150 -0.002207
# ...          ...       ...       ...       ...       ...       ...
# 1254  2022-10-31  2.554215  0.867376 -0.033000 -0.464012  0.496090
# 1255  2022-11-01  2.598770  0.875130 -0.038230 -0.465006  0.510414
# 1256  2022-11-02  2.456518  0.754857 -0.074839 -0.482811  0.486256
# 1257  2022-11-03  2.296629  0.667403 -0.099943 -0.484894  0.438134
# 1258  2022-11-04  2.297326  0.649732 -0.092098 -0.481438  0.459543
#
# [1259 rows x 6 columns]

# %%
series.plot(x = "Date", y = "AAPL")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
plot_acf(x = series["AAPL"])

# %%
series.plot(x = "Date", y = "AMZN")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
plot_acf(x = series["AMZN"])

# %%
series.plot(x = "Date", y = "FSPTX")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
plot_acf(x = series["FSPTX"])

# %%
series.plot(x = "Date", y = "SHRAX")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
plot_acf(x = series["SHRAX"])

# %%
series.plot(x = "Date", y = "SPY")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
plot_acf(x = series["SPY"])

# %%
# fit model
# model = ARIMA("insert data here", order = ())
